# %%
# !pip install gitpython
# Out:
# Requirement already satisfied: gitpython in /home/oscar/miniconda3/envs/jupyter/lib/python3.10/site-packages (3.1.43)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/oscar/miniconda3/envs/jupyter/lib/python3.10/site-packages (from gitpython) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/oscar/miniconda3/envs/jupyter/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.1)

# %%
import os
import fnmatch
import tempfile
import git
import shutil
import requests

def clone_repo(repo_url, target_dir):
    try:
        git.Repo.clone_from(repo_url, target_dir)
        print(f"Cloned {repo_url} to {target_dir}")
    except Exception as e:
        print(f"Failed to clone {repo_url}: {e}")

def find_files_by_extension(root_dir, extensions):
    matches = []
    for root, _, files in os.walk(root_dir):
        for ext in extensions:
            for file in fnmatch.filter(files, f"*{ext}"):
                matches.append(os.path.join(root, file))
    return matches

def get_repo_name_from_url(repo_url):
    # Extract the repository name from the URL (e.g., 'user/repo_name')
    return os.path.splitext(os.path.basename(repo_url))[0]

def copy_files_to_directory(files, destination_dir, repo_name):
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    for file_path in files:
        # Append repository name to the file name to avoid collisions
        file_name = os.path.basename(file_path)
        new_file_name = f"{repo_name}_{file_name}"
        
        # Determine the destination path
        destination_path = os.path.join(destination_dir, new_file_name)
        try:
            shutil.copy(file_path, destination_path)
            print(f"Copied {file_path} to {destination_path}")
        except Exception as e:
            print(f"Failed to copy {file_path}: {e}")

def fetch_and_copy_files(github_links, extensions, output_dir):
    # Use a temporary directory to clone the repos
    with tempfile.TemporaryDirectory() as temp_dir:
        for link in github_links:
            repo_name = get_repo_name_from_url(link)
            project_dir = os.path.join(temp_dir, repo_name)
            clone_repo(link, project_dir)
            files = find_files_by_extension(project_dir, extensions)
            if files:
                copy_files_to_directory(files, output_dir, repo_name)
            else:
                print(f"No files found for extensions {extensions} in {link}")
    # Temporary directory will automatically be deleted after exiting this block

def fetch_repos(username, per_page=100):
    """
    Fetch all repositories for a given GitHub user.
    """
    repos = []
    url = f"https://api.github.com/users/{username}/repos"
    params = {'per_page': per_page, 'page': 1}
    
    while True:
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Failed to fetch repositories for user {username}: {response.status_code}")
            break
        
        data = response.json()
        if not data:
            break
        
        repos.extend(data)
        params['page'] += 1

    repos = [repo['html_url'] for repo in repos]
    return repos


# Example usage
if __name__ == "__main__":
    github_links = fetch_repos("Oscar-gg")
    print("github_links:", github_links)
    current_file_path = os.path.abspath('')
    extensions = [".py", ".md"]
    output_dir = os.path.join(current_file_path, "assets")  # Change this to your desired output location

    fetch_and_copy_files(github_links, extensions, output_dir)
# Out:
# github_links: ['https://github.com/Oscar-gg/Atemoc', 'https://github.com/Oscar-gg/awak-game', 'https://github.com/Oscar-gg/Candidates2022', 'https://github.com/Oscar-gg/cemex_hacks_2023', 'https://github.com/Oscar-gg/cva_scripts', 'https://github.com/Oscar-gg/deep-person-reid', 'https://github.com/Oscar-gg/EventManager', 'https://github.com/Oscar-gg/GithubExample', 'https://github.com/Oscar-gg/gitweb', 'https://github.com/Oscar-gg/HACKmty-2023', 'https://github.com/Oscar-gg/IvanRomero03', 'https://github.com/Oscar-gg/joyas-jeans-project', 'https://github.com/Oscar-gg/Oscar-gg', 'https://github.com/Oscar-gg/Oscar-gg.github.io', 'https://github.com/Oscar-gg/portfolio', 'https://github.com/Oscar-gg/Programacion-Competitiva', 'https://github.com/Oscar-gg/rbrgs-convertidor-horario', 'https://github.com/Oscar-gg/sample-project', 'https://github.com/Oscar-gg/save_links', 'https://github.com/Oscar-gg/Smart-Office', 'https://github.com/Oscar-gg/smart_office', 'https://github.com/Oscar-gg/smart_office_nodemcu', 'https://github.com/Oscar-gg/TaskRegister', 'https://github.com/Oscar-gg/TC2005B', 'https://github.com/Oscar-gg/TC2005BAct_2', 'https://github.com/Oscar-gg/TC2038_algoritmos', 'https://github.com/Oscar-gg/Whisper-VAD', 'https://github.com/Oscar-gg/zoom-script']
# Cloned https://github.com/Oscar-gg/Atemoc to /tmp/tmprebtw51k/Atemoc
# Copied /tmp/tmprebtw51k/Atemoc/main.py to /home/oscar/Repositories/portfolio/rag/assets/Atemoc_main.py
# Copied /tmp/tmprebtw51k/Atemoc/README.md to /home/oscar/Repositories/portfolio/rag/assets/Atemoc_README.md
# Cloned https://github.com/Oscar-gg/awak-game to /tmp/tmprebtw51k/awak-game
# Copied /tmp/tmprebtw51k/awak-game/README.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_README.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/MaterialUI/README.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_README.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/i5 Toolkit for Unity/LICENSE.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_LICENSE.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/i5 Toolkit for Unity/README.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_README.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/i5 Toolkit for Unity/CHANGELOG.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_CHANGELOG.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/i5 Toolkit for Unity/Runtime/Utilities/Async/License.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_License.md
# Copied /tmp/tmprebtw51k/awak-game/Assets/i5 Toolkit for Unity/Runtime/Utilities/Async/ReadMe.md to /home/oscar/Repositories/portfolio/rag/assets/awak-game_ReadMe.md
# Cloned https://github.com/Oscar-gg/Candidates2022 to /tmp/tmprebtw51k/Candidates2022
# Copied /tmp/tmprebtw51k/Candidates2022/README.md to /home/oscar/Repositories/portfolio/rag/assets/Candidates2022_README.md
# Cloned https://github.com/Oscar-gg/cemex_hacks_2023 to /tmp/tmprebtw51k/cemex_hacks_2023
# Copied /tmp/tmprebtw51k/cemex_hacks_2023/README.md to /home/oscar/Repositories/portfolio/rag/assets/cemex_hacks_2023_README.md
# Cloned https://github.com/Oscar-gg/cva_scripts to /tmp/tmprebtw51k/cva_scripts
# Copied /tmp/tmprebtw51k/cva_scripts/folder_text.py to /home/oscar/Repositories/portfolio/rag/assets/cva_scripts_folder_text.py
# Copied /tmp/tmprebtw51k/cva_scripts/cva_dependencies.py to /home/oscar/Repositories/portfolio/rag/assets/cva_scripts_cva_dependencies.py
# Copied /tmp/tmprebtw51k/cva_scripts/reduce_image.py to /home/oscar/Repositories/portfolio/rag/assets/cva_scripts_reduce_image.py
# Copied /tmp/tmprebtw51k/cva_scripts/README.md to /home/oscar/Repositories/portfolio/rag/assets/cva_scripts_README.md
# Cloned https://github.com/Oscar-gg/deep-person-reid to /tmp/tmprebtw51k/deep-person-reid
# Copied /tmp/tmprebtw51k/deep-person-reid/setup.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_setup.py
# Copied /tmp/tmprebtw51k/deep-person-reid/tools/compute_mean_std.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_compute_mean_std.py
# Copied /tmp/tmprebtw51k/deep-person-reid/tools/export.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_export.py
# Copied /tmp/tmprebtw51k/deep-person-reid/tools/parse_test_res.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_parse_test_res.py
# Copied /tmp/tmprebtw51k/deep-person-reid/tools/visualize_actmap.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_visualize_actmap.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/README.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_README.md
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/default_parser.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_default_parser.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/main.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_main.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/README.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_README.md
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/models/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/models/osnet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_osnet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/datasets/pa100k.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_pa100k.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/datasets/dataset.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_dataset.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/attribute_recognition/datasets/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/DML/dml.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_dml.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/DML/default_config.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_default_config.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/DML/main.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_main.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/DML/README.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_README.md
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/softmax_nas.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_softmax_nas.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/default_config.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_default_config.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/main.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_main.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/osnet_child.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_osnet_child.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/osnet_search.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_osnet_search.py
# Copied /tmp/tmprebtw51k/deep-person-reid/projects/OSNet_AIN/README.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_README.md
# Copied /tmp/tmprebtw51k/deep-person-reid/docs/conf.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_conf.py
# Copied /tmp/tmprebtw51k/deep-person-reid/docs/AWESOME_REID.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_AWESOME_REID.md
# Copied /tmp/tmprebtw51k/deep-person-reid/docs/MODEL_ZOO.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_MODEL_ZOO.md
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datamanager.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_datamanager.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/sampler.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_sampler.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/transforms.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_transforms.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/dataset.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_dataset.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/cuhk03.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_cuhk03.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/sensereid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_sensereid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/cuhk01.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_cuhk01.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/msmt17.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_msmt17.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/university1652.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_university1652.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/dukemtmcreid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_dukemtmcreid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/prid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_prid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/market1501.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_market1501.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/ilids.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_ilids.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/grid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_grid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/cuhk02.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_cuhk02.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/cuhksysu.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_cuhksysu.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/image/viper.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_viper.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/video/ilidsvid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_ilidsvid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/video/prid2011.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_prid2011.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/video/dukemtmcvidreid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_dukemtmcvidreid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/video/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/data/datasets/video/mars.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_mars.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/optim/optimizer.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_optimizer.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/optim/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/optim/lr_scheduler.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_lr_scheduler.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/optim/radam.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_radam.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/hacnn.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_hacnn.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/pcb.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_pcb.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/osnet_ain.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_osnet_ain.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/densenet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_densenet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/resnet_ibn_b.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_resnet_ibn_b.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/shufflenet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_shufflenet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/xception.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_xception.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/mobilenetv2.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_mobilenetv2.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/senet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_senet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/inceptionv4.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_inceptionv4.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/mlfn.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_mlfn.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/shufflenetv2.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_shufflenetv2.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/resnet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_resnet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/squeezenet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_squeezenet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/osnet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_osnet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/resnet_ibn_a.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_resnet_ibn_a.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/resnetmid.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_resnetmid.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/nasnet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_nasnet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/mudeep.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_mudeep.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/models/inceptionresnetv2.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_inceptionresnetv2.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/losses/cross_entropy_loss.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_cross_entropy_loss.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/losses/hard_mine_triplet_loss.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_hard_mine_triplet_loss.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/losses/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/engine.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_engine.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/image/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/image/softmax.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_softmax.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/image/triplet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_triplet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/video/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/video/softmax.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_softmax.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/engine/video/triplet.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_triplet.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/model_complexity.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_model_complexity.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/rerank.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_rerank.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/torchtools.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_torchtools.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/feature_extractor.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_feature_extractor.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/avgmeter.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_avgmeter.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/reidtools.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_reidtools.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/tools.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_tools.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/loggers.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_loggers.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/gnn_reranking.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_gnn_reranking.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/utils.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_utils.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/main.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_main.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/README.md to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_README.md
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/extension/adjacency_matrix/setup.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_setup.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/utils/GPU-Re-Ranking/extension/propagation/setup.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_setup.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/rank.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_rank.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/distance.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_distance.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/accuracy.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_accuracy.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/rank_cylib/__init__.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid___init__.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/rank_cylib/test_cython.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_test_cython.py
# Copied /tmp/tmprebtw51k/deep-person-reid/torchreid/metrics/rank_cylib/setup.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_setup.py
# Copied /tmp/tmprebtw51k/deep-person-reid/scripts/default_config.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_default_config.py
# Copied /tmp/tmprebtw51k/deep-person-reid/scripts/main.py to /home/oscar/Repositories/portfolio/rag/assets/deep-person-reid_main.py
# Cloned https://github.com/Oscar-gg/EventManager to /tmp/tmprebtw51k/EventManager
# Copied /tmp/tmprebtw51k/EventManager/README.md to /home/oscar/Repositories/portfolio/rag/assets/EventManager_README.md
# Cloned https://github.com/Oscar-gg/GithubExample to /tmp/tmprebtw51k/GithubExample
# Copied /tmp/tmprebtw51k/GithubExample/test.py to /home/oscar/Repositories/portfolio/rag/assets/GithubExample_test.py
# Cloned https://github.com/Oscar-gg/gitweb to /tmp/tmprebtw51k/gitweb
# Copied /tmp/tmprebtw51k/gitweb/README.md to /home/oscar/Repositories/portfolio/rag/assets/gitweb_README.md
# Cloned https://github.com/Oscar-gg/HACKmty-2023 to /tmp/tmprebtw51k/HACKmty-2023
# Copied /tmp/tmprebtw51k/HACKmty-2023/README.md to /home/oscar/Repositories/portfolio/rag/assets/HACKmty-2023_README.md
# Copied /tmp/tmprebtw51k/HACKmty-2023/BanorteCoach/README.md to /home/oscar/Repositories/portfolio/rag/assets/HACKmty-2023_README.md
# Cloned https://github.com/Oscar-gg/IvanRomero03 to /tmp/tmprebtw51k/IvanRomero03
# Copied /tmp/tmprebtw51k/IvanRomero03/README.md to /home/oscar/Repositories/portfolio/rag/assets/IvanRomero03_README.md
# Cloned https://github.com/Oscar-gg/joyas-jeans-project to /tmp/tmprebtw51k/joyas-jeans-project
# Copied /tmp/tmprebtw51k/joyas-jeans-project/README.md to /home/oscar/Repositories/portfolio/rag/assets/joyas-jeans-project_README.md
# Cloned https://github.com/Oscar-gg/Oscar-gg to /tmp/tmprebtw51k/Oscar-gg
# Copied /tmp/tmprebtw51k/Oscar-gg/README.md to /home/oscar/Repositories/portfolio/rag/assets/Oscar-gg_README.md
# Cloned https://github.com/Oscar-gg/Oscar-gg.github.io to /tmp/tmprebtw51k/Oscar-gg.github
# Copied /tmp/tmprebtw51k/Oscar-gg.github/README.md to /home/oscar/Repositories/portfolio/rag/assets/Oscar-gg.github_README.md
# Cloned https://github.com/Oscar-gg/portfolio to /tmp/tmprebtw51k/portfolio
# Copied /tmp/tmprebtw51k/portfolio/README.md to /home/oscar/Repositories/portfolio/rag/assets/portfolio_README.md
# Copied /tmp/tmprebtw51k/portfolio/src/data/utils/technologies.py to /home/oscar/Repositories/portfolio/rag/assets/portfolio_technologies.py
# Cloned https://github.com/Oscar-gg/Programacion-Competitiva to /tmp/tmprebtw51k/Programacion-Competitiva
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/README.md to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_README.md
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/vjudgeTec/semana1/g.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_g.py
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/RAMcpp/topic/numberTheory/compgcd.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_compgcd.py
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/RAMcpp/topic/numberTheory/d.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_d.py
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/RAMcpp/topic/numberTheory/e.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_e.py
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/RAMcpp/topic/numberTheory/bigfactorial.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_bigfactorial.py
# Copied /tmp/tmprebtw51k/Programacion-Competitiva/RAMcpp/CAMP/day1/diagnostic/f.py to /home/oscar/Repositories/portfolio/rag/assets/Programacion-Competitiva_f.py
# Cloned https://github.com/Oscar-gg/rbrgs-convertidor-horario to /tmp/tmprebtw51k/rbrgs-convertidor-horario
# Copied /tmp/tmprebtw51k/rbrgs-convertidor-horario/README.md to /home/oscar/Repositories/portfolio/rag/assets/rbrgs-convertidor-horario_README.md
# Cloned https://github.com/Oscar-gg/sample-project to /tmp/tmprebtw51k/sample-project
# No files found for extensions ['.py', '.md'] in https://github.com/Oscar-gg/sample-project
# Cloned https://github.com/Oscar-gg/save_links to /tmp/tmprebtw51k/save_links
# Copied /tmp/tmprebtw51k/save_links/save_links.py to /home/oscar/Repositories/portfolio/rag/assets/save_links_save_links.py
# Copied /tmp/tmprebtw51k/save_links/README.md to /home/oscar/Repositories/portfolio/rag/assets/save_links_README.md
# Cloned https://github.com/Oscar-gg/Smart-Office to /tmp/tmprebtw51k/Smart-Office
# Copied /tmp/tmprebtw51k/Smart-Office/README.md to /home/oscar/Repositories/portfolio/rag/assets/Smart-Office_README.md
# Cloned https://github.com/Oscar-gg/smart_office to /tmp/tmprebtw51k/smart_office
# Copied /tmp/tmprebtw51k/smart_office/README.md to /home/oscar/Repositories/portfolio/rag/assets/smart_office_README.md
# Copied /tmp/tmprebtw51k/smart_office/faker/faker.py to /home/oscar/Repositories/portfolio/rag/assets/smart_office_faker.py
# Copied /tmp/tmprebtw51k/smart_office/docs/general.md to /home/oscar/Repositories/portfolio/rag/assets/smart_office_general.md
# Cloned https://github.com/Oscar-gg/smart_office_nodemcu to /tmp/tmprebtw51k/smart_office_nodemcu
# Copied /tmp/tmprebtw51k/smart_office_nodemcu/README.md to /home/oscar/Repositories/portfolio/rag/assets/smart_office_nodemcu_README.md
# Cloned https://github.com/Oscar-gg/TaskRegister to /tmp/tmprebtw51k/TaskRegister
# Copied /tmp/tmprebtw51k/TaskRegister/README.md to /home/oscar/Repositories/portfolio/rag/assets/TaskRegister_README.md
# Cloned https://github.com/Oscar-gg/TC2005B to /tmp/tmprebtw51k/TC2005B
# No files found for extensions ['.py', '.md'] in https://github.com/Oscar-gg/TC2005B
# Cloned https://github.com/Oscar-gg/TC2005BAct_2 to /tmp/tmprebtw51k/TC2005BAct_2
# No files found for extensions ['.py', '.md'] in https://github.com/Oscar-gg/TC2005BAct_2
# Cloned https://github.com/Oscar-gg/TC2038_algoritmos to /tmp/tmprebtw51k/TC2038_algoritmos
# Copied /tmp/tmprebtw51k/TC2038_algoritmos/README.md to /home/oscar/Repositories/portfolio/rag/assets/TC2038_algoritmos_README.md
# Cloned https://github.com/Oscar-gg/Whisper-VAD to /tmp/tmprebtw51k/Whisper-VAD
# Copied /tmp/tmprebtw51k/Whisper-VAD/PlayAudio.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_PlayAudio.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/RecordAudio.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_RecordAudio.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/speech_to_text/vad.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_vad.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/speech_to_text/openai_api.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_openai_api.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/speech_to_text/SpeechNode.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_SpeechNode.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/speech_to_text/audio_transcriber.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_audio_transcriber.py
# Copied /tmp/tmprebtw51k/Whisper-VAD/speech_to_text/utils/audio_utils.py to /home/oscar/Repositories/portfolio/rag/assets/Whisper-VAD_audio_utils.py
# Cloned https://github.com/Oscar-gg/zoom-script to /tmp/tmprebtw51k/zoom-script
# Copied /tmp/tmprebtw51k/zoom-script/README.md to /home/oscar/Repositories/portfolio/rag/assets/zoom-script_README.md
